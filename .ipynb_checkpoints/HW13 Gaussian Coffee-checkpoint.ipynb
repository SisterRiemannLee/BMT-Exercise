# %% [markdown]
# # Assignment 13

# %%
from scipy.stats import poisson, norm, binom
import numpy as np
# %matplotlib notebook
from matplotlib import pyplot as plt

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Part a.)

# %% [markdown]
# ![title](Images\Pic_13_2_a.png)

# %%
mu=5 + 2/3 # (500 + 200/300)/100

# %% [markdown]
# for help with any opperators in this notebook us the `?` opperator. e.g.:
#
# ```?poisson.ppf```
#
#
# inverse function of distribution.... --> where is the e.g. 0.99 procentile of my distribution with this mu?

# %%
x = np.arange(poisson.ppf(0.01, mu), poisson.ppf(0.99, mu))
fig, axs = plt.subplots(ncols=2, figsize=(10, 4))
axs[0].plot(x, poisson.pmf(x, mu), 'bo', ms=8)
axs[0].set_title(label='poisson pmf')
axs[1].plot(x, poisson.cdf(x, mu), 'x', ms=8)
axs[1].set_title(label='poisson cdf')
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Text(0.5, 1.0, 'poisson cdf')

# %%
p = 1 - 5/3 * np.exp(-2/3)
print('more than one bug in a particular method {0:.0%}'.format(p))
# Out:
# more than one bug in a particular method 14%

# %% [markdown]
# ### Part b.)
#
# Since each patient has 50% chance of choosing each hospital --> 1000 coin flips
#
# To solve this problem, we will be using the scipy binomial formula implementation; the documentation of which can be found [here](https://docs.scipy.org/doc/scipy/reference/tutorial/stats/discrete_binom.html?highlight=binomial).
#
# The brute-force method:

# %% [markdown]
# ![title](Images\Pic_13_2_b.png)

# %%
binom.pmf(1000, 1000, 0.5) # propbability everyone goes to one hosipital
# Out:
# 9.332636185032827e-302

# %%
x=0
p_refusal= 0.01
p_choice = 0.5
N_patients = 1000
i = N_patients + 1
while x<p_refusal:
    i=i-1
    x=x+binom.pmf(i, N_patients, p_choice)

print('Both hospitals needs {} beds\n'.format(i));
# Out:
# Both hospitals needs 537 beds

# %% [markdown]
# #### plot distribution

# %%
X=np.arange(0,N_patients)
Y = binom.pmf(X,N_patients,p_choice)
Y_c = binom.cdf(X,N_patients,p_choice)

fig, axs = plt.subplots(ncols=2, figsize=(10, 4))
axs[0].grid(True)
axs[0].plot(X,Y,'r',LineWidth=2); 
axs[0].set_title('Binomial PDF N={}, p={}'.format(N_patients,p_refusal));

axs[1].grid(True)
axs[1].plot(X,Y_c,'r',LineWidth=2);
axs[1].plot([0, 1000],[0.99, 0.99],'b--',LineWidth=2);
axs[1].set_title('Binomial CDF N={}, p={}'.format(N_patients,p_refusal)); # Cumulative distribution function
# Out:
# <img src="data:image/png;base64,..." width="1500">
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':

# %%
# calculate the nice way

i_e = binom.ppf(0.99,N_patients,p_choice)
print('Both hospitals needs {} beds\n'.format(int(i_e)))
# Out:
# Both hospitals needs 537 beds

# %% [markdown]
# ### Part c.)

# %% [markdown]
# ![title](Images\Pic_13_2_c.png)

# %%
p_left = 0.04
N_students = 25
i_e = binom.pmf(0, N_students, p_left)
print('{0:.0%} percent likelihood no lef-handed students\n'.format(i_e))
# Out:
# 36% percent likelihood no lef-handed students

# %% [markdown]
# ## Exercise 3
# #### a.) we know that $\mu = 55$ and  `norm.cdf(50,$\mu$, $\sigma$)` = 0.1

# %% [markdown]
# ![title](Images\Pic_13_3_a.png)

# %%
z = norm.ppf(0.1, 0, 1)
mu = 55
x = 50
sigma = (x - mu) / z
print(sigma)
# Out:
# 3.9015207303618955

# %% [markdown]
# #### let's check our result

# %%
norm.cdf(x, mu, sigma)
# Out:
# 0.10000000000000009

# %% [markdown]
# #### b.) The precentage of cups that contain more than 61 ml:

# %% [markdown]
# ![title](Images\Pic_13_3_b.png)

# %%
p = 1 - norm.cdf(61, mu, sigma)
print('~ {0:.0%} \n'.format(p))
# Out:
# ~ 6%

# %% [markdown]
# #### c.) After adjustment, we have $\sigma = 3$ and `norm.cdf(50, $\mu$, $\sigma^2$) = 0.025`. Thus as in a.)

# %% [markdown]
# ![title](Images\Pic_13_3_c.png)

# %%
sigma = 3
z = norm.ppf(0.025, 0, 1)
mu = x - z * sigma
print("{}ml per cup of coffee".format(mu))
# Out:
# 55.87989195362016ml per cup of coffee

# %%
# x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
# fig, axs = plt.subplots(ncols=2, figsize=(10, 4))
# axs[0].plot(x, norm.pdf(x), ms=8, color="orange")
# axs[0].set_title(label='normal pdf', color="orange")
# axs[1].plot(x, norm.cdf(x), ms=8, color="maroon")
# axs[1].set_title(label='normal cdf', color="maroon")
