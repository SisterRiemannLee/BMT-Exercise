# %% [markdown]
# Seems that need to add some pictures to make the page more readable

# %%
# from IPython.display import Image
# Image(filename="Pic_1.png", width=500, height=1000)
# showing with this method is not very readable......

# It seems that showing with the following command leads to a very big image......

# %% [markdown]
# ![title](Pic_1.png)

# %%
#####################################################################
#
#  
#   main file for the demonstration of the Burt Adelson pyramid
#   written by: Maximilian Baust & Rüdiger Göbl
#               Chair for Computer Aided Medical Procedures
#               & Augmented Reality
#               Technische Universität München
#               10-22-2017
#
#####################################################################

import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize


# this function performs the linear combinaton of the images.
# you will have to enter your implementation here
def linear_combination(alpha, d, r):

    # Initialize I with the residual
    i_alpha = r;

    # add linearly combined difference images
    for i in range(0, len(alpha)):
        i_alpha = i_alpha + alpha[i]*d[:,:,i];

    return i_alpha

def cost_function(alpha, i_orig, d, r):
    # compute linear combination
    i = linear_combination(alpha, d, r)

    # compute sum of absolute differences
    sad = np.sum(np.abs(i_orig - i))
    return sad

# %%
# load image data
data = np.load('data.npz')
I_orig = data['I_orig']
I_noisy = data['I_noisy']
R = data['R']
D = data['D']

# show original image
fig = plt.figure()
fig.add_subplot(1, 2, 1)
plt.imshow(I_orig, cmap="gray")
plt.title('original image')
plt.draw()

# show noisy image
fig.add_subplot(1, 2, 2)
plt.imshow(I_noisy, cmap="gray")
plt.title('noisy image')
plt.draw()

# %%
# show difference images and residual part
fig = plt.figure()
fig.add_subplot(2, 3, 1)
plt.imshow(D[:, :, 0], cmap="gray")
plt.title('difference image 1')
plt.draw()

fig.add_subplot(2, 3, 2)
plt.imshow(D[:, :, 1], cmap="gray")
plt.title('difference image 2')
plt.draw()

fig.add_subplot(2, 3, 3)
plt.imshow(D[:, :, 2], cmap="gray")
plt.title('difference image 3')
plt.draw()

fig.add_subplot(2, 3, 4)
plt.imshow(D[:, :, 3], cmap="gray")
plt.title('difference image 4')
plt.draw()

fig.add_subplot(2, 3, 5)
plt.imshow(D[:, :, 4], cmap="gray")
plt.title('difference image 5')
plt.draw()

fig.add_subplot(2, 3, 6)
plt.imshow(R, cmap="gray")
plt.title('residual part')
plt.draw()

# %%
# show sum of difference images and residual part
plt.figure()
plt.imshow(np.sum(D, -1) + R, cmap="gray")
plt.title('sum of difference images and residual part')
plt.show()

# %%
# find optimal linear combination
alpha0 = np.ones(5)
alpha = scipy.optimize.fmin(
    lambda a : cost_function(a, I_orig, D, R),
    x0=alpha0
)
# Out:
# Optimization terminated successfully.
#          Current function value: 161.068730
#          Iterations: 300
#          Function evaluations: 495

# %%
# show found linear combination
plt.figure()
plt.imshow(linear_combination(alpha, D, R), cmap="gray")
plt.title('denoised image')
plt.show()

# %%
# show difference to original image
plt.figure()
plt.imshow(abs(I_orig - linear_combination(alpha, D, R)), cmap="gray")
plt.title('difference to original image')
plt.show()

# %% [markdown]
# ![title](Pic_2.png)

# %%
alpha
# Out:
# array([-0.03615234,  2.99934831, -1.24093387, -2.37671265,  7.32618693])

# %% [markdown]
# If you are interested in understanding the details of this assignment, have a look at the following publication: *P.J. Burt and E.H. Adelson, The Laplacian Pyramid as a Compact Image Code, IEEE Transactions on Communications, April 1983.*
